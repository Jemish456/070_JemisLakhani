# %% [markdown]
# #Task2: Try Linear regression on same prediction data using Tensorflow

# %%
import numpy as np
import tensorflow as tf

# %%
inputs = np.array([[73, 67, 43], [91, 88, 64], [87, 134, 58], [102, 43, 37], [69, 96, 70],[73, 67, 43], [91, 88, 64], 
                   [87, 134, 58], [102, 43, 37], [69, 96, 70], [73, 67, 43], [91, 88, 64], [87, 134, 58], [102, 43, 37], 
                   [69, 96, 70]], dtype='float64')

targets = np.array([[56, 70], [81, 101], [119, 133], [22, 37], [103, 119],[56, 70], [81, 101], [119, 133], [22, 37], 
                    [103, 119],[56, 70], [81, 101], [119, 133], [22, 37], [103, 119]], dtype='float64')

# %%
inputs = tf.Variable(inputs)
targets = tf.Variable(targets)
print("targets :\n",targets)
# Out:
# targets :
#  <tf.Variable 'Variable:0' shape=(15, 2) dtype=float64, numpy=
# array([[ 56.,  70.],
#        [ 81., 101.],
#        [119., 133.],
#        [ 22.,  37.],
#        [103., 119.],
#        [ 56.,  70.],
#        [ 81., 101.],
#        [119., 133.],
#        [ 22.,  37.],
#        [103., 119.],
#        [ 56.,  70.],
#        [ 81., 101.],
#        [119., 133.],
#        [ 22.,  37.],
#        [103., 119.]])>

# %%
v = np.random.rand(3,2)
r = np.random.randn(2)
v = tf.Variable(v)
r = tf.Variable(r)

print(v)
print("\n",r)
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[0.05941016, 0.21421521],
#        [0.42196142, 0.3371672 ],
#        [0.25314963, 0.52750079]])>
#
#  <tf.Variable 'Variable:0' shape=(2,) dtype=float64, numpy=array([-0.49750594,  1.15037299])>

# %%
def model(s):
    return s @ v + r

# %%
prediction = model(inputs)
print(prediction)
# Out:
# tf.Tensor(
# [[42.99628454 62.06081959]
#  [58.24299936 84.07472112]
#  [75.8966862  95.56254699]
#  [33.07320725 57.01604296]
#  [61.83056506 85.22432892]
#  [42.99628454 62.06081959]
#  [58.24299936 84.07472112]
#  [75.8966862  95.56254699]
#  [33.07320725 57.01604296]
#  [61.83056506 85.22432892]
#  [42.99628454 62.06081959]
#  [58.24299936 84.07472112]
#  [75.8966862  95.56254699]
#  [33.07320725 57.01604296]
#  [61.83056506 85.22432892]], shape=(15, 2), dtype=float64)

# %%
def mse(t1,t2):
    return tf.reduce_mean(tf.square(t1 - t2))
print(mse(prediction,targets))
# Out:
# tf.Tensor(765.4908117910165, shape=(), dtype=float64)

# %%
epochs = 40
for epoch_count in range(epochs):
    
    with tf.GradientTape(persistent=True) as t:
        current_loss = mse(targets, model(inputs))

    v1 = t.gradient(current_loss,v)
    r1 = t.gradient(current_loss,r)

    v.assign_sub(1e-4 * v1)
    r.assign_sub(1e-4 * r1)
        
    print(f" \n Epoch count: {epoch_count} \n Loss value: {current_loss.numpy()}")
# Out:
#
#  Epoch count: 0
#  Loss value: 765.4908117910165
#
#  Epoch count: 1
#  Loss value: 558.427191518326
#
#  Epoch count: 2
#  Loss value: 419.50852342418597
#
#  Epoch count: 3
#  Loss value: 324.36518711807156
#
#  Epoch count: 4
#  Loss value: 257.6114237527858
#
#  Epoch count: 5
#  Loss value: 209.49894023431645
#
#  Epoch count: 6
#  Loss value: 173.82130790886896
#
#  Epoch count: 7
#  Loss value: 146.601112014972
#
#  Epoch count: 8
#  Loss value: 125.26701389396882
#
#  Epoch count: 9
#  Loss value: 108.13749983087231
#
#  Epoch count: 10
#  Loss value: 94.09666656425678
#
#  Epoch count: 11
#  Loss value: 82.39029747506466
#
#  Epoch count: 12
#  Loss value: 72.49732664548013
#
#  Epoch count: 13
#  Loss value: 64.04858327214428
#
#  Epoch count: 14
#  Loss value: 56.775218009697
#
#  Epoch count: 15
#  Loss value: 50.47578904176452
#
#  Epoch count: 16
#  Loss value: 44.99510129179593
#
#  Epoch count: 17
#  Loss value: 40.210468265248785
#
#  Epoch count: 18
#  Loss value: 36.0226787983956
#
#  Epoch count: 19
#  Loss value: 32.349960992052154
#
#  Epoch count: 20
#  Loss value: 29.12386838529177
#
#  Epoch count: 21
#  Loss value: 26.286410096537576
#
#  Epoch count: 22
#  Loss value: 23.78799552643052
#
#  Epoch count: 23
#  Loss value: 21.585920530333496
#
#  Epoch count: 24
#  Loss value: 19.64322030420609
#
#  Epoch count: 25
#  Loss value: 17.927776225846
#
#  Epoch count: 26
#  Loss value: 16.411603100243713
#
#  Epoch count: 27
#  Loss value: 15.07026815463655
#
#  Epoch count: 28
#  Loss value: 13.88240902817712
#
#  Epoch count: 29
#  Loss value: 12.829328231909805
#
#  Epoch count: 30
#  Loss value: 11.894648204443225
#
#  Epoch count: 31
#  Loss value: 11.064015467500319
#
#  Epoch count: 32
#  Loss value: 10.324845316820252
#
#  Epoch count: 33
#  Loss value: 9.666100486083788
#
#  Epoch count: 34
#  Loss value: 9.078098621836773
#
#  Epoch count: 35
#  Loss value: 8.552344413025684
#
#  Epoch count: 36
#  Loss value: 8.08138296159768
#
#  Epoch count: 37
#  Loss value: 7.658671545102408
#
#  Epoch count: 38
#  Loss value: 7.278467362898876
#
#  Epoch count: 39
#  Loss value: 6.935729210044527
